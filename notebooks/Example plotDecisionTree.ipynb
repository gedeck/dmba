# %% [markdown]
# # Example notebook to demonstrate the use of plotDecisionTree
#
# (c) 2023 Galit Shmueli, Peter C. Bruce, Peter Gedeck

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import dmba

# %matplotlib inline
# Out:
# no display found. Using non-interactive Agg backend

# %%
mower_df = dmba.load_data('RidingMowers.csv')

classTree = DecisionTreeClassifier(random_state=0, max_depth=1)
classTree.fit(mower_df.drop(columns=['Ownership']), mower_df['Ownership'])

print("Classes: {}".format(', '.join(classTree.classes_)))
dmba.plotDecisionTree(classTree, feature_names=mower_df.columns[:2], class_names=classTree.classes_)
# Out:
# Classes: Nonowner, Owner

# %%
bank_df = dmba.load_data('UniversalBank.csv')
bank_df = bank_df.drop(columns=['ID', 'ZIP Code'])

X = bank_df.drop(columns=['Personal Loan'])
y = bank_df['Personal Loan']
train_X, valid_X, train_y, valid_y = train_test_split(X, y, test_size=0.4, random_state=1)

fullClassTree = DecisionTreeClassifier()
fullClassTree.fit(train_X, train_y)

dmba.plotDecisionTree(fullClassTree, feature_names=train_X.columns)
